# %% [markdown]
# # MCP + Llama3.1 Demo
#
# This notebook connects to the local MCP server (`http://localhost:8000/mcp`),
# discovers its tools, and hands them to **Llama3.1** running in Ollama.
#
# > **Prerequisites**
# > 1. MCP server running: `cd .. && .venv/bin/python server.py`
# > 2. Ollama running with llama3.1: `ollama serve`

# %% [markdown]
# ## 1. Config

# %%
MCP_SERVER_URL = "https://mcp-hello-world.mangoflower-6dbfeafb.centralus.azurecontainerapps.io/mcp"
MODEL          = "llama3.1"

# %% [markdown]
# ## 2. Imports

# %%
import ollama
from fastmcp import Client

# %% [markdown]
# ## 3. Inspect MCP tools
#
# Connect to the server and print what tools are registered.

# %%
client = Client(MCP_SERVER_URL)

# %%
async def list_mcp_tools():
    async with client:
        # fastmcp.Client returns a plain list of MCP tool descriptors
        return await client.list_tools()

tools = await list_mcp_tools()
for t in tools:
    print(f"  tool: {t.name}")
    print(f"  desc: {t.description}")
    print(f"  schema: {t.inputSchema}")
    print()
# Out:
#   tool: hello_world
#   desc: Returns a simple Hello World greeting.
#   schema: {'additionalProperties': False, 'properties': {}, 'type': 'object'}
#
#   tool: echo
#   desc: Returns the input string.
#   schema: {'additionalProperties': False, 'properties': {'input': {'type': 'string'}}, 'required': ['input'], 'type': 'object'}

# %% [markdown]
# ## 4. Chat with Llama3.3 + MCP tools
#
# Full agentic loop:
# 1. Send user message + available tools to Llama3.3
# 2. If Llama requests a tool call, execute it via MCP
# 3. Feed the result back and get the final response

# %%
def mcp_tools_to_ollama(mcp_tools):
    """Convert MCP tool descriptors to Ollama's tool format."""
    return [
        {
            "type": "function",
            "function": {
                "name": t.name,
                "description": t.description,
                "parameters": t.inputSchema,
            },
        }
        for t in mcp_tools
    ]


async def chat(user_message: str) -> str:
    # Use the fastmcp Client created in the earlier connection cell.
    async with client:
        mcp_tools = await client.list_tools()
        ollama_tools = mcp_tools_to_ollama(mcp_tools)

        messages = [{"role": "user", "content": user_message}]
        print(f"User: {user_message}\n")

        # Agentic loop — keep going until no more tool calls
        while True:
            response = ollama.chat(
                model=MODEL,
                messages=messages,
                tools=ollama_tools,
            )
            msg = response.message
            messages.append(msg)

            if not msg.tool_calls:
                break  # Llama is done, return final text

            # Execute each requested tool via MCP
            for tc in msg.tool_calls:
                name = tc.function.name
                args = dict(tc.function.arguments or {})
                print(f"  [tool call]  {name}({args})")

                mcp_result = await client.call_tool(name, args)
                text = mcp_result.content[0].text if mcp_result.content else ""
                print(f"  [tool result] {text}\n")

                messages.append({"role": "tool", "content": text})

        final = msg.content
        print(f"Llama3.1: {final}")
        return final

# %% [markdown]
# ## 5. Run it

# %%
await chat("Use the echo tool!")
# Out:
# User: Use the echo tool!
#
#   [tool call]  echo({'input': 'Use the echo tool!'})
#   [tool result] Use the echo tool!
#
# Llama3.1: It looks like you asked me to use the echo tool, which I just did. Now it's my turn again. What would you like me to do with the echo tool?
# "It looks like you asked me to use the echo tool, which I just did. Now it's my turn again. What would you like me to do with the echo tool?"
